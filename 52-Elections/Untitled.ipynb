# %%
from matplotlib import pyplot as plt
import numpy as np

plt.xkcd()

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(111)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35, c='red')
  ax.text(dx + i * dx, 0.6, 'W', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, 'J', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# result
ax.text(0.9, 0.6, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# ax.set_ylim(0.2, 1)
plt.axis('off');
plt.tight_layout()
plt.savefig('pic1.png')

# %%
fig = plt.figure(figsize=(24, 8))
ax = plt.subplot(121)


N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, 'W' if i > 2 else 'J', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, 'J' if i > 2 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# result
ax.text(0.9, 0.6, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

plt.axis('off');
ax = plt.subplot(122)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, 'J' if i > 3 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# result
ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# ax.set_ylim(0.2, 1)
plt.axis('off');
plt.tight_layout()
plt.savefig('pic2.png')

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(111)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, 'W' if i > 2 else 'J', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, 'J' if i > 2 else 'F', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.2, 'F' if i > 2 else 'W', ha='center', va='center', size=50, c='gray')
# result
ax.text(0.9, 0.6, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'J', ha='center', va='center', size=50)
ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

plt.axis('off');
# ax = plt.subplot(122)

# N = 6
# dx = 0.8 / (N + 1)

# # voters
# for i in range(N):
#   ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
#   ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.4, 'J' if i > 3 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# # result
# ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# # ax.set_ylim(0.2, 1)
# plt.axis('off');
plt.tight_layout()
plt.savefig('pic3.png')

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(111)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, 'W' if i == 3 else 'J' if i > 2 else 'F', ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.2, 'F' if i > 2 else 'W', ha='center', va='center', size=50, c='gray')
# result
ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

plt.axis('off');
# ax = plt.subplot(122)

# N = 6
# dx = 0.8 / (N + 1)

# # voters
# for i in range(N):
#   ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
#   ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.4, 'J' if i > 3 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# # result
# ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# # ax.set_ylim(0.2, 1)
# plt.axis('off');
plt.tight_layout()
plt.savefig('pic4.png')

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(111)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  if (i < 3):
    a = ['F', 'J', 'W']
  elif (i == 3):
    a = ['J', 'W', 'F']
  else:
    a = ['W', 'F', 'J']
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, a[0], ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, a[1], ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.2, a[2], ha='center', va='center', size=50, c='gray')
# result
ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

plt.axis('off');
# ax = plt.subplot(122)

# N = 6
# dx = 0.8 / (N + 1)

# # voters
# for i in range(N):
#   ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
#   ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.4, 'J' if i > 3 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# # result
# ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# # ax.set_ylim(0.2, 1)
# plt.axis('off');
plt.tight_layout()
plt.savefig('pic5.png')

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(111)

N = 6
dx = 0.8 / (N + 1)

# voters
for i in range(N):
  if (i < 3):
    a = ['F', 'J', 'W']
  elif (i == 3):
    a = ['J', 'W', 'F']
  else:
    a = ['W', 'F', 'J']
  ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
  ax.text(dx + i * dx, 0.6, a[0], ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.4, a[1], ha='center', va='center', size=50, c='gray')
  ax.text(dx + i * dx, 0.2, a[2], ha='center', va='center', size=50, c='gray')
# result
ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

plt.axis('off');
# ax = plt.subplot(122)

# N = 6
# dx = 0.8 / (N + 1)

# # voters
# for i in range(N):
#   ax.text(dx + i * dx, 0.8, i + 1, ha='center', va='center', size=35 if i != 3 else 60, c='red' if i != 3 else 'royalblue')
#   ax.text(dx + i * dx, 0.6, 'W' if i > 3 else 'J', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.4, 'J' if i > 3 else 'W', ha='center', va='center', size=50, c='gray')
#   ax.text(dx + i * dx, 0.2, 'F', ha='center', va='center', size=50, c='lightgray')
# # result
# ax.text(0.9, 0.6, 'J', ha='center', va='center', size=50)
# ax.text(0.9, 0.4, 'W', ha='center', va='center', size=50)
# ax.text(0.9, 0.2, 'F', ha='center', va='center', size=50)

# # ax.set_ylim(0.2, 1)
# plt.axis('off');
plt.tight_layout()
# plt.savefig('pic6.png')
