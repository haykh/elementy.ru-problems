# %%
fig, ax = plt.subplots(figsize=(6, 4), dpi=300)
ax.plot(range(100))
ax.set_title(r'number density', size=32)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$r/\Delta x$')
ax.set_ylabel(r'monoplace')
plt.show()
